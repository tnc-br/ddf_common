# %% [markdown]
# <a href="https://colab.research.google.com/github/tnc-br/ddf_common/blob/harness_as_df/harness_as_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This colab loads all the data in the DDF harness bigquery table and stores it into a dataframe.
#
# First, update your bigquery api (you will need to restart the runtime after this step).

# %%
# %pip install --upgrade google-cloud-bigquery

# %% [markdown]
# ### Dependencies

# %%
# This stub (ddfimport) allows the Ddf EE API to be imported.
import sys
# !if [ ! -d "/content/ddf_common_stub" ] ; then git clone -b test https://github.com/tnc-br/ddf_common_stub.git; fi
sys.path.append("/content/ddf_common_stub/")
import ddfimport
ddfimport.ddf_import_common()

# %%
import importlib
import eeddf
import bqddf
importlib.reload(eeddf)
importlib.reload(bqddf)

# Use your credentials to access the BQ tables.
eeddf.initialize_ddf(test_environment = True)

# %% [markdown]
# ### Load the data

# %%
def get_all_training_results():
  client = bqddf._get_big_query_client()

  # Set up SQL query
  table_name = f"{bqddf._CONFIG['DATASET']}.{bqddf._CONFIG['FLATTENED_TABLE']}"
  query = f"SELECT * FROM {table_name}"

  # Execute the query
  results = client.query_and_wait(query)
  return results

results = get_all_training_results()

# %%
# Results is iterator based, so you will get an error running this twice!
df = results.to_dataframe()

# %%
df
# Out:
#                  training_id  num_epochs  num_layers  num_nodes_per_layer  \
# 0            test-2024-08-16        5000           2                   20
# 1       test-2024-08-23-demo        5000           2                   20
# 2            test-2024-08-23        5000           3                   20
# 3            test-2024-09-13        5000           2                   20
# 4            test-2024-09-16        5000           2                   20
# 5      test-2024-09-18-ruben        5000           2                   20
# 6            test-2024-09-20        5000           2                   20
# 7          test-2024-09-20-1        5000           2                   20
# 8            test-2024-09-28        5000           2                   20
# 9   test-2024-10-11-wsg-test        5000           2                   20
# 10           test-2024-10-25        5000           2                   20
# 11         test-2024-10-25-1        5000           2                   20
#
#     training_batch_size  learning_rate  dropout_rate activation_func  \
# 0                     5         0.0001           0.0            relu
# 1                     5         0.0001           0.0            relu
# 2                     5         0.0001           0.0            relu
# 3                     5         0.0001           0.0            relu
# 4                     5         0.0001           0.0            relu
# 5                     5         0.0001           0.0            relu
# 6                     5         0.0001           0.0            relu
# 7                     5         0.0001           0.0            relu
# 8                     5         0.0001           0.0            relu
# 9                     5         0.0001           0.0            relu
# 10                    5         0.0001           0.0            relu
# 11                    5         0.0001           0.0            relu
#
#     early_stopping_patience  double_sided_kl  ...  mean_rmse  var_rmse  \
# 0                       100            False  ...   1.424710  1.894904
# 1                       100            False  ...   0.905705  2.336453
# 2                       100            False  ...   1.492808  1.517098
# 3                       100            False  ...   2.074457  1.199077
# 4                       100            False  ...  26.052463  1.253441
# 5                       100            False  ...   0.905705  2.336453
# 6                       100            False  ...   0.905705  2.336453
# 7                       100            False  ...   0.905705  2.336453
# 8                       100            False  ...   1.202759  1.797841
# 9                       100            False  ...   0.895919  2.332339
# 10                      100            False  ...   0.895919  2.332339
# 11                      100            False  ...   1.303818  2.126160
#
#     overall_rmse                                         dataset_id  \
# 0       1.659807  /content/gdrive/MyDrive/amazon_rainforest_file...
# 1       1.621079  /content/gdrive/MyDrive/amazon_rainforest_file...
# 2       1.504953  /content/gdrive/MyDrive/amazon_rainforest_file...
# 3       1.636767  /content/gdrive/MyDrive/amazon_rainforest_file...
# 4      13.652952  /content/gdrive/MyDrive/amazon_rainforest_file...
# 5       1.621079  /content/gdrive/MyDrive/amazon_rainforest_file...
# 6       1.621079  /content/gdrive/MyDrive/amazon_rainforest_file...
# 7       1.621079  /content/gdrive/MyDrive/amazon_rainforest_file...
# 8       1.500300  /content/gdrive/MyDrive/amazon_rainforest_file...
# 9       1.614129  /content/gdrive/MyDrive/amazon_rainforest_file...
# 10      1.614129  /content/gdrive/MyDrive/amazon_rainforest_file...
# 11      1.714989  /content/gdrive/MyDrive/amazon_rainforest_file...
#
#    completion_timestamp  radius_pace  \
# 0                   NaT          100
# 1                   NaT          100
# 2                   NaT          100
# 3                   NaT          100
# 4                   NaT          100
# 5                   NaT          100
# 6                   NaT          100
# 7                   NaT          100
# 8                   NaT          100
# 9                   NaT          100
# 10                  NaT          100
# 11                  NaT          100
#
#                                       per_radius_eval                 tags  \
# 0   [{'radius': 6, 'auc': 0.4576826478835413, 'p_v...                   []
# 1   [{'radius': 6, 'auc': 0.45850478539018547, 'p_...                   []
# 2   [{'radius': 6, 'auc': 0.45730572108020995, 'p_...                   []
# 3   [{'radius': 6, 'auc': 0.49726006931876554, 'p_...  [author:ruru, ViNN]
# 4   [{'radius': 6, 'auc': 0.5113636363636362, 'p_v...  [author:ruru, ViNN]
# 5   [{'radius': 6, 'auc': 0.45850478539018547, 'p_...  [author:ruru, ViNN]
# 6   [{'radius': 6, 'auc': 0.45850478539018547, 'p_...  [author:ruru, ViNN]
# 7   [{'radius': 6, 'auc': 0.45850478539018547, 'p_...  [author:ruru, ViNN]
# 8   [{'radius': 6, 'auc': 0.4700859931402744, 'p_v...  [author:ruru, ViNN]
# 9   [{'radius': 6, 'auc': 0.45958520453304974, 'p_...  [author:ruru, ViNN]
# 10  [{'radius': 6, 'auc': 0.45958520453304974, 'p_...  [author:ruru, ViNN]
# 11  [{'radius': 6, 'auc': 0.45374729183300716, 'p_...   [author:npr, ViNN]
#
#                                               as_json  trusted_buffer_radius
# 0                                                None                   <NA>
# 1                                                None                   <NA>
# 2                                                None                   <NA>
# 3   {'activation_func': 'relu', 'double_sided_kl':...                      5
# 4   {'activation_func': 'relu', 'double_sided_kl':...                      5
# 5   {'activation_func': 'relu', 'double_sided_kl':...                      5
# 6   {'activation_func': 'relu', 'double_sided_kl':...                      5
# 7   {'activation_func': 'relu', 'double_sided_kl':...                      5
# 8   {'activation_func': 'relu', 'double_sided_kl':...                      5
# 9   {'activation_func': 'relu', 'double_sided_kl':...                      5
# 10  {'activation_func': 'relu', 'double_sided_kl':...                      5
# 11  {'activation_func': 'relu', 'double_sided_kl':...                      5
#
# [12 rows x 31 columns]
