# %% [markdown]
# <a href="https://colab.research.google.com/github/tnc-br/ddf_common/blob/FirestoreTest/TestPRD_Harness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This stub (ddfimport) allows the Ddf EE API to be imported.
import sys
# !if [ ! -d "/content/ddf_common_stub" ] ; then git clone -b test https://github.com/tnc-br/ddf_common_stub.git; fi
sys.path.append("/content/ddf_common_stub/")
import ddfimport

# Use this line to import from a branch of the github repository.
# It will git clone the git repository under a google drive path.
# This allows you to modify the source files by opening the file view and
# changing files under /content/gdrive/MyDrive/
ddfimport.ddf_source_control_pane()
# Out:
# Cloning into 'ddf_common_stub'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 18 (delta 7), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (18/18), 7.36 KiB | 3.68 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# interactive(children=(Text(value='', description='Email', placeholder='Enter email'), Text(value='', descripti…

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import os

# open https://pantheon.corp.google.com/iam-admin/serviceaccounts/details/101022385268487960539?project=timberid-prd&supportedpurview=project
# to obtain a json key file and place it in your Drive folder in the path indicated below
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/gdrive/MyDrive/Harness/timberid-prd-key.json"
cred = credentials.ApplicationDefault()

firebase_admin.initialize_app(cred)
db = firestore.client()

# TODO: Here is where we need to set data for a new Test Sample
# See https://firebase.corp.google.com/u/0/project/timberid-prd/firestore/databases/-default-/data/~2Fusers~2Falovelace
doc_ref = db.collection("untrusted_samples").document("0185cd77639d5653ec41")
print(u'Document data: {}'.format(doc_ref.get().to_dict()))


# TODO: Wait...

# TODO: and read result
# Out:
# Document data: {'org_name': 'Google', 'created_by': 'iY1nSo70geNbXzf7ZztWn4NR2Vk2', 'validity_details': {'d18O_cel_reference_variance': 1.4932208061218262, 'reference_oxygen_isoscape_recall': '0.3181818181818182', 'p_value_threshold': 0.006658830241521474, 'd18O_cel_sample_variance': 3.424000000000001, 'reference_oxygen_isoscape_name': 'stamped_canonical', 'p_value': 0.42807405605593973, 'reference_oxygen_isoscape_creation_date': '09/26/2023 22:16:42', 'p_value_carbon': 1, 'p_value_oxygen': 0.42807405605593973, 'd18O_cel_reference_mean': 25.03463363647461, 'p_value_nitrogen': 1, 'reference_oxygen_isoscape_precision': '1.0', 'd18O_cel_sample_mean': 24.2}, 'lat': -2.499, 'last_updated_by': 'Ben Wulfe', 'created_on': '5-17-2024', 'land_use_anthropic_pct': {'2020': 0.00013295002921840415, '2013': 8.381632276812436e-05, '2012': 6.358479658271503e-05, '2015': 0.00014451090132435235, '2014': 0.00011271850303299483, '2018': 0.0002745707125162695, '2019': 0.0002687902764632954, '2021': 0.00013295002921840415, '2011': 6.358479658271503e-05, '2017': 0.0002630098404103213, '2016': 0.0002601196223838342}, 'created_by_name': 'Ben Wulfe', 'c_wood': [], 'site': 'Costa Marques-Site', 'trusted': 'untrusted', 'status': 'concluded', 'd13C_cel': [], 'land_use_secondary_vegetation_or_regrowth_pct': {'2018': 8.67065407946114e-06, '2015': 8.67065407946114e-06, '2011': 4.0463052370818655e-05, '2019': 1.4451090132435235e-05, '2017': 2.8902180264870467e-06, '2021': 0.00015029133737732645, '2012': 4.0463052370818655e-05, '2020': 0.00015029133737732645, '2013': 2.890218026487047e-05, '2016': 2.8902180264870467e-06, '2014': 1.734130815892228e-05}, 'd15N_wood': [11, 11, 11, 11, 11], 'points': [{'d18O_wood': '22', 'd15N_wood': '11', 'n_wood': '.5', 'd18O_cel': '23.6'}, {'n_wood': '.5', 'd15N_wood': '11', 'd18O_wood': '22', 'd18O_cel': '23.6'}, {'d15N_wood': '11', 'n_wood': '.5', 'd18O_wood': '22', 'd18O_cel': '24.2'}, {'d18O_wood': '22', 'd18O_cel': '22', 'd15N_wood': '11', 'n_wood': '.5'}, {'n_wood': '.5', 'd15N_wood': '11', 'd18O_cel': '27.6', 'd18O_wood': '22'}], 'sample_name': 'SampleName1947', 'org': '918b6441f4d152c4a4ae', 'validity': 'Possible', 'lon': -59.121, 'water_pct': {'is_point_water': False, 'water_mean_in_1km_buffer': 0, 'water_mean_in_10km_buffer': 0}, 'land_use_primary_vegetation_pct': {'2021': 0.9997167586334043, '2014': 0.999869940188808, '2016': 0.9997369901595897, '2012': 0.9998959521510464, '2017': 0.9997340999415631, '2019': 0.9997167586334043, '2011': 0.9998959521510464, '2018': 0.9997167586334043, '2013': 0.999887281496967, '2015': 0.9998468184445962, '2020': 0.9997167586334043}, 'd18O_cel': [23.6, 23.6, 24.2, 22, 27.6], 'd18O_wood': [22, 22, 22, 22, 22], 'code_lab': '0185cd77639d5653ec41', 'c_cel': [], 'd13C_wood': [], 'visibility': 'private', 'n_wood': [0.5, 0.5, 0.5, 0.5, 0.5], 'collected_by': 'supplier'}
